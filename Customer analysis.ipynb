# %%
import pandas as pd

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\mtriv\Downloads\customer_shopping_behavior.csv")

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# Load CSV first
df = pd.read_csv(r"C:\Users\mtriv\Downloads\customer_shopping_behavior.csv")

# PostgreSQL connection details
username = "postgres"
password = "Veni@2005"
host = "localhost"
port = "5432"
database = "mydatabase"  # Change to your actual database name

# Create connection
engine = create_engine(
    f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
)

# Write DataFrame to PostgreSQL
table_name = "mytable"

try:
    df.to_sql(table_name, engine, if_exists='replace', index=False)
    print(f"Data successfully loaded into table '{table_name}'")

    # Read back sample
    result = pd.read_sql(f"SELECT * FROM {table_name} LIMIT 5;", engine)
    print(result)

except Exception as e:
    print("Error:", e)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 15
#      12 database = "mydatabase"  # Change to your actual database name
#      14 # Create connection
# ---> 15 engine = create_engine(
#      16     f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
#      17 )
#      19 # Write DataFrame to PostgreSQL
#      20 table_name = "mytable"
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\util\deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# ...

# %%
# !pip install psycopg2-binary
# Out:
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.8 MB 9.7 MB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.8 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 8.9 MB/s  0:00:00
# ...

# %%
import psycopg2
print(psycopg2.__version__)
# Out:
# 2.9.12 (dt dec pq3 ext lo64)

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\mtriv\anaconda3\python.exe

# %%
import pandas as pd
from sqlalchemy import create_engine

# Load CSV first
df = pd.read_csv(r"C:\Users\mtriv\Downloads\customer_shopping_behavior.csv")

# PostgreSQL connection details
username = "postgres"
password = "Veni%402005"
host = "localhost"
port = "5432"
database = "customer_behavior"  # Change to your actual database name

# Create connection
engine = create_engine(
    f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
)

# Write DataFrame to PostgreSQL
table_name = "customer"

try:
    df.to_sql(table_name, engine, if_exists='replace', index=False)
    print(f"Data successfully loaded into table '{table_name}'")

    # Read back sample
    result = pd.read_sql(f"SELECT * FROM {table_name} LIMIT 5;", engine)
    print(result)

except Exception as e:
    print("Error:", e)
# Out:
# Data successfully loaded into table 'customer'
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...
